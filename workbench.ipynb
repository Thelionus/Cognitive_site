# %%
# @title 1. Install Libraries
# Pin cryptography<44 to satisfy pydrive2 and pyopenssl constraints
# !pip install -q sendgrid google-generativeai pandas "cryptography>=41.0.5,<44"
print("✅ Libraries installed.")
